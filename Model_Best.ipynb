# %%
from google.colab import drive
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, precision_score
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn import svm
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
drive.mount('/content/drive')

data = pd.read_csv('/content/drive/Shared drives/539 Project/final_df.csv')
# Out:
# Mounted at /content/drive

# %%
df = data.copy()
#this gives a y that is 1 if the driver won the race, otherwise 0, the response we are predicting is the winner, that is y=1
df.podium = df.podium.map(lambda x: 1 if x == 1 else 0)

train = df[df.season <2020]
X_train = train.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_train = train.podium

X_train
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns)

# %%
#parametrs are optimzed from a grid search in Model_alt.ipynb
model = RandomForestClassifier(criterion = "entropy", max_features = "auto", max_depth = None)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
df = data.copy()
#this gives a y that is 1 if the driver won the race, otherwise 0, the response we are predicting is the winner, that is y=1
#df.podium = df.podium.map(lambda x: 1 if x == 1 else 0)
#this goes through every race in 2020 just so I could get a picture of exactly what the model is predicting
# predicting mostly Hamilton wins which I don't find surpising
train = df[df.season <2020]
X_train = train.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
print(X_train.shape)
y_train = train.podium

#X_train.to_csv("X_train.csv")

scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns)
# Out:
# (2353, 56)

# %%
test = df[(df.season == 2020) & (df['round'] == 1)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
X_test.to_csv("X_test.csv")
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = (prediction_df.index) + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.57     0.43           bottas       1          1
# 1      0.72     0.28   max_verstappen      20          2
# 2      0.84     0.16           norris       3          3
# 3      0.89     0.11         hamilton       4          4
# 4      0.92     0.08            albon      13          5
# 5      0.98     0.02        ricciardo      19          6
# 6      0.98     0.02           vettel      10          7
# 7      0.99     0.01         grosjean      16          8
# 8      1.00     0.00            sainz       5          9
# 9      1.00     0.00           stroll      18         10
# 10     1.00     0.00          leclerc       2         11
# 11     1.00     0.00            perez       6         12
# 12     1.00     0.00            gasly       7         13
# 13     1.00     0.00            kvyat      12         14
# 14     1.00     0.00             ocon       8         15
# 15     1.00     0.00  kevin_magnussen      17         16
# 16     1.00     0.00          russell      15         17
# 17     1.00     0.00       giovinazzi       9         18
# 18     1.00     0.00        raikkonen      14         19
# 19     1.00     0.00           latifi      11         20

# %%
test = df[(df.season == 2020) & (df['round'] == 2)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.60     0.40         hamilton       1          1
# 1      0.89     0.11   max_verstappen       3          2
# 2      0.95     0.05            albon       4          3
# 3      0.95     0.05           bottas       2          4
# 4      0.99     0.01           norris       5          5
# 5      0.99     0.01           vettel      20          6
# 6      1.00     0.00            gasly      15          7
# 7      1.00     0.00        ricciardo       8          8
# 8      1.00     0.00             ocon      18          9
# 9      1.00     0.00            sainz       9         10
# 10     1.00     0.00          russell      16         11
# 11     1.00     0.00           stroll       7         12
# 12     1.00     0.00            kvyat      10         13
# 13     1.00     0.00          leclerc      19         14
# 14     1.00     0.00  kevin_magnussen      12         15
# 15     1.00     0.00        raikkonen      11         16
# 16     1.00     0.00            perez       6         17
# 17     1.00     0.00           latifi      17         18
# 18     1.00     0.00       giovinazzi      14         19

# %%
test = df[(df.season == 2020) & (df['round'] == 3)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1          driver  actual  predicted
# 0      0.32     0.68        hamilton       1          1
# 1      0.74     0.26          bottas       3          2
# 2      0.93     0.07          norris      13          3
# 3      0.96     0.04           albon       5          4
# 4      0.98     0.02  max_verstappen       2          5
# 5      0.99     0.01          stroll       4          6
# 6      0.99     0.01           perez       7          7
# 7      0.99     0.01           sainz       9          8
# 8      1.00     0.00      giovinazzi      17          9
# 9      1.00     0.00           kvyat      12         10
# 10     1.00     0.00          latifi      19         11
# 11     1.00     0.00            ocon      14         12
# 12     1.00     0.00           gasly      20         13
# 13     1.00     0.00         russell      18         14
# 14     1.00     0.00       ricciardo       8         15
# 15     1.00     0.00         leclerc      11         16
# 16     1.00     0.00          vettel       6         17
# 17     1.00     0.00       raikkonen      15         18

# %%
test = df[(df.season == 2020) & (df['round'] == 4)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.32     0.68         hamilton       1          1
# 1      0.74     0.26           bottas      11          2
# 2      0.97     0.03       hulkenberg      20          3
# 3      0.99     0.01   max_verstappen       2          4
# 4      0.99     0.01           norris       5          5
# 5      0.99     0.01           stroll       9          6
# 6      1.00     0.00            kvyat      18          7
# 7      1.00     0.00           latifi      15          8
# 8      1.00     0.00         grosjean      16          9
# 9      1.00     0.00        raikkonen      17         10
# 10     1.00     0.00       giovinazzi      14         11
# 11     1.00     0.00  kevin_magnussen      19         12
# 12     1.00     0.00            gasly       7         13
# 13     1.00     0.00            albon       8         14
# 14     1.00     0.00           vettel      10         15
# 15     1.00     0.00             ocon       6         16
# 16     1.00     0.00        ricciardo       4         17
# 17     1.00     0.00            sainz      13         18
# 18     1.00     0.00          leclerc       3         19
# 19     1.00     0.00          russell      12         20

# %%
test = df[(df.season == 2020) & (df['round'] == 5)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.46     0.54         hamilton       2          1
# 1      0.51     0.49           bottas       3          2
# 2      0.98     0.02           norris       9          3
# 3      0.98     0.02            sainz      13          4
# 4      0.98     0.02           vettel      12          5
# 5      0.98     0.02   max_verstappen       1          6
# 6      0.99     0.01        ricciardo      14          7
# 7      0.99     0.01       hulkenberg       7          8
# 8      1.00     0.00           stroll       6          9
# 9      1.00     0.00            gasly      11         10
# 10     1.00     0.00          leclerc       4         11
# 11     1.00     0.00            albon       5         12
# 12     1.00     0.00         grosjean      16         13
# 13     1.00     0.00             ocon       8         14
# 14     1.00     0.00          russell      18         15
# 15     1.00     0.00            kvyat      10         16
# 16     1.00     0.00  kevin_magnussen      20         17
# 17     1.00     0.00           latifi      19         18
# 18     1.00     0.00       giovinazzi      17         19
# 19     1.00     0.00        raikkonen      15         20

# %%
test = df[(df.season == 2020) & (df['round'] == 6)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.33     0.67         hamilton       1          1
# 1      0.82     0.18           bottas       3          2
# 2      0.89     0.11   max_verstappen       2          3
# 3      0.97     0.03            albon       8          4
# 4      0.99     0.01          leclerc      20          5
# 5      0.99     0.01           vettel       7          6
# 6      1.00     0.00            sainz       6          7
# 7      1.00     0.00           norris      10          8
# 8      1.00     0.00           stroll       4          9
# 9      1.00     0.00            gasly       9         10
# 10     1.00     0.00            perez       5         11
# 11     1.00     0.00            kvyat      12         12
# 12     1.00     0.00        ricciardo      11         13
# 13     1.00     0.00        raikkonen      14         14
# 14     1.00     0.00             ocon      13         15
# 15     1.00     0.00  kevin_magnussen      15         16
# 16     1.00     0.00         grosjean      19         17
# 17     1.00     0.00          russell      17         18
# 18     1.00     0.00           latifi      18         19
# 19     1.00     0.00       giovinazzi      16         20

# %%
test = df[(df.season == 2020) & (df['round'] == 7)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.33     0.67         hamilton       1          1
# 1      0.83     0.17   max_verstappen       3          2
# 2      0.86     0.14           bottas       2          3
# 3      0.96     0.04            albon       6          4
# 4      0.98     0.02        ricciardo       4          5
# 5      0.99     0.01            perez      10          6
# 6      0.99     0.01           stroll       9          7
# 7      1.00     0.00           vettel      13          8
# 8      1.00     0.00           latifi      16          9
# 9      1.00     0.00       giovinazzi      18         10
# 10     1.00     0.00         grosjean      15         11
# 11     1.00     0.00        raikkonen      12         12
# 12     1.00     0.00          russell      19         13
# 13     1.00     0.00            kvyat      11         14
# 14     1.00     0.00          leclerc      14         15
# 15     1.00     0.00            gasly       8         16
# 16     1.00     0.00           norris       7         17
# 17     1.00     0.00            sainz      20         18
# 18     1.00     0.00             ocon       5         19
# 19     1.00     0.00  kevin_magnussen      17         20

# %%
test = df[(df.season == 2020) & (df['round'] == 8)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.18     0.82         hamilton       7          1
# 1      0.76     0.24           bottas       5          2
# 2      0.91     0.09   max_verstappen      17          3
# 3      0.95     0.05            albon      15          4
# 4      0.98     0.02            sainz       2          5
# 5      0.98     0.02            perez      10          6
# 6      0.98     0.02           norris       4          7
# 7      1.00     0.00        raikkonen      13          8
# 8      1.00     0.00          russell      14          9
# 9      1.00     0.00       giovinazzi      16         10
# 10     1.00     0.00           vettel      20         11
# 11     1.00     0.00         grosjean      12         12
# 12     1.00     0.00  kevin_magnussen      19         13
# 13     1.00     0.00            kvyat       9         14
# 14     1.00     0.00          leclerc      18         15
# 15     1.00     0.00             ocon       8         16
# 16     1.00     0.00            gasly       1         17
# 17     1.00     0.00           stroll       3         18
# 18     1.00     0.00        ricciardo       6         19
# 19     1.00     0.00           latifi      11         20

# %%
test = df[(df.season == 2020) & (df['round'] == 9)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.20     0.80         hamilton       1          1
# 1      0.73     0.27           bottas       2          2
# 2      0.80     0.20   max_verstappen      19          3
# 3      0.94     0.06            albon       3          4
# 4      0.98     0.02           norris       6          5
# 5      0.99     0.01           stroll      13          6
# 6      0.99     0.01            sainz      18          7
# 7      0.99     0.01            gasly      20          8
# 8      1.00     0.00            perez       5          9
# 9      1.00     0.00        ricciardo       4         10
# 10     1.00     0.00             ocon      14         11
# 11     1.00     0.00          leclerc       8         12
# 12     1.00     0.00            kvyat       7         13
# 13     1.00     0.00        raikkonen       9         14
# 14     1.00     0.00           vettel      10         15
# 15     1.00     0.00         grosjean      12         16
# 16     1.00     0.00       giovinazzi      17         17
# 17     1.00     0.00          russell      11         18
# 18     1.00     0.00           latifi      15         19
# 19     1.00     0.00  kevin_magnussen      16         20

# %%
test = df[(df.season == 2020) & (df['round'] == 10)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.18     0.82         hamilton       3          1
# 1      0.74     0.26   max_verstappen       2          2
# 2      0.87     0.13           bottas       1          3
# 3      0.96     0.04            albon      10          4
# 4      0.97     0.03           norris      15          5
# 5      0.98     0.02            sainz      19          6
# 6      0.98     0.02            gasly       9          7
# 7      0.99     0.01            perez       4          8
# 8      1.00     0.00           vettel      13          9
# 9      1.00     0.00        raikkonen      14         10
# 10     1.00     0.00  kevin_magnussen      12         11
# 11     1.00     0.00       giovinazzi      11         12
# 12     1.00     0.00         grosjean      17         13
# 13     1.00     0.00            kvyat       8         14
# 14     1.00     0.00          russell      18         15
# 15     1.00     0.00           stroll      20         16
# 16     1.00     0.00          leclerc       6         17
# 17     1.00     0.00             ocon       7         18
# 18     1.00     0.00        ricciardo       5         19
# 19     1.00     0.00           latifi      16         20

# %%
test = df[(df.season == 2020) & (df['round'] == 11)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.33     0.67         hamilton       1          1
# 1      0.72     0.28   max_verstappen       2          2
# 2      0.81     0.19           bottas      19          3
# 3      0.91     0.09            albon      17          4
# 4      0.98     0.02           norris      16          5
# 5      0.99     0.01          leclerc       7          6
# 6      0.99     0.01            sainz       5          7
# 7      0.99     0.01            gasly       6          8
# 8      1.00     0.00  kevin_magnussen      13          9
# 9      1.00     0.00        raikkonen      12         10
# 10     1.00     0.00           latifi      14         11
# 11     1.00     0.00          russell      20         12
# 12     1.00     0.00         grosjean       9         13
# 13     1.00     0.00           vettel      11         14
# 14     1.00     0.00       giovinazzi      10         15
# 15     1.00     0.00            kvyat      15         16
# 16     1.00     0.00            perez       4         17
# 17     1.00     0.00             ocon      18         18
# 18     1.00     0.00        ricciardo       3         19
# 19     1.00     0.00       hulkenberg       8         20

# %%
test = df[(df.season == 2020) & (df['round'] == 12)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.50     0.50         hamilton       1          1
# 1      0.72     0.28   max_verstappen       3          2
# 2      0.87     0.13           bottas       2          3
# 3      0.96     0.04            albon      12          4
# 4      0.97     0.03        ricciardo       9          5
# 5      0.99     0.01          leclerc       4          6
# 6      0.99     0.01            perez       7          7
# 7      0.99     0.01            gasly       5          8
# 8      0.99     0.01           stroll      20          9
# 9      1.00     0.00           vettel      10         10
# 10     1.00     0.00  kevin_magnussen      16         11
# 11     1.00     0.00         grosjean      17         12
# 12     1.00     0.00       giovinazzi      15         13
# 13     1.00     0.00        raikkonen      11         14
# 14     1.00     0.00             ocon       8         15
# 15     1.00     0.00          russell      14         16
# 16     1.00     0.00            kvyat      19         17
# 17     1.00     0.00           norris      13         18
# 18     1.00     0.00            sainz       6         19
# 19     1.00     0.00           latifi      18         20

# %%
test = df[(df.season == 2020) & (df['round'] == 13)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.61     0.39         hamilton       1          1
# 1      0.77     0.23           bottas       2          2
# 2      0.81     0.19   max_verstappen      17          3
# 3      0.98     0.02           stroll      13          4
# 4      0.99     0.01            perez       6          5
# 5      0.99     0.01        ricciardo       3          6
# 6      0.99     0.01            gasly      20          7
# 7      1.00     0.00            albon      15          8
# 8      1.00     0.00          leclerc       5          9
# 9      1.00     0.00            kvyat       4         10
# 10     1.00     0.00           norris       8         11
# 11     1.00     0.00            sainz       7         12
# 12     1.00     0.00             ocon      19         13
# 13     1.00     0.00          russell      16         14
# 14     1.00     0.00           vettel      12         15
# 15     1.00     0.00         grosjean      14         16
# 16     1.00     0.00  kevin_magnussen      18         17
# 17     1.00     0.00        raikkonen       9         18
# 18     1.00     0.00           latifi      11         19
# 19     1.00     0.00       giovinazzi      10         20

# %%
test = df[(df.season == 2020) & (df['round'] == 14)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.64     0.36   max_verstappen       6          1
# 1      0.64     0.36         hamilton       1          2
# 2      0.85     0.15           bottas      14          3
# 3      0.90     0.10           stroll       9          4
# 4      0.93     0.07        ricciardo      10          5
# 5      0.94     0.06            albon       7          6
# 6      0.97     0.03            gasly      13          7
# 7      0.97     0.03            perez       2          8
# 8      0.98     0.02             ocon      11          9
# 9      0.98     0.02            sainz       5         10
# 10     0.99     0.01           vettel       3         11
# 11     0.99     0.01          leclerc       4         12
# 12     0.99     0.01           norris       8         13
# 13     1.00     0.00        raikkonen      15         14
# 14     1.00     0.00  kevin_magnussen      17         15
# 15     1.00     0.00            kvyat      12         16
# 16     1.00     0.00         grosjean      18         17
# 17     1.00     0.00       giovinazzi      20         18

# %%
test = df[(df.season == 2020) & (df['round'] == 15)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1           driver  actual  predicted
# 0      0.38     0.62         hamilton       1          1
# 1      0.70     0.30           bottas       8          2
# 2      0.81     0.19   max_verstappen       2          3
# 3      0.92     0.08            albon       3          4
# 4      0.97     0.03           stroll      19          5
# 5      0.98     0.02            perez      18          6
# 6      0.99     0.01        ricciardo       7          7
# 7      0.99     0.01            gasly       6          8
# 8      0.99     0.01           norris       4          9
# 9      0.99     0.01          leclerc      10         10
# 10     0.99     0.01            sainz       5         11
# 11     1.00     0.00       giovinazzi      16         12
# 12     1.00     0.00         grosjean      20         13
# 13     1.00     0.00  kevin_magnussen      17         14
# 14     1.00     0.00        raikkonen      15         15
# 15     1.00     0.00           vettel      13         16
# 16     1.00     0.00          russell      12         17
# 17     1.00     0.00            kvyat      11         18
# 18     1.00     0.00             ocon       9         19
# 19     1.00     0.00           latifi      14         20

# %%
test = df[(df.season == 2020) & (df['round'] == 16)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1             driver  actual  predicted
# 0      0.59     0.41             bottas       8          1
# 1      0.65     0.35            russell       9          2
# 2      0.73     0.27     max_verstappen      19          3
# 3      0.95     0.05            leclerc      20          4
# 4      0.96     0.04              albon       6          5
# 5      0.97     0.03          ricciardo       5          6
# 6      0.97     0.03              sainz       4          7
# 7      0.98     0.02              perez       1          8
# 8      0.98     0.02             stroll       3          9
# 9      0.98     0.02             norris      10         10
# 10     0.99     0.01              kvyat       7         11
# 11     0.99     0.01              gasly      11         12
# 12     1.00     0.00             latifi      18         13
# 13     1.00     0.00          raikkonen      14         14
# 14     1.00     0.00             aitken      16         15
# 15     1.00     0.00               ocon       2         16
# 16     1.00     0.00    kevin_magnussen      15         17
# 17     1.00     0.00         giovinazzi      13         18
# 18     1.00     0.00             vettel      12         19
# 19     1.00     0.00  pietro_fittipaldi      17         20

# %%
test = df[(df.season == 2020) & (df['round'] == 17)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)

# %%
prediction_df
# Out:
#     proba_0  proba_1             driver  actual  predicted
# 0      0.56     0.44     max_verstappen       1          1
# 1      0.62     0.38           hamilton       3          2
# 2      0.65     0.35             bottas       2          3
# 3      0.95     0.05             norris       5          4
# 4      0.97     0.03             stroll      10          5
# 5      0.98     0.02          ricciardo       7          6
# 6      0.98     0.02              albon       4          7
# 7      0.99     0.01               ocon       9          8
# 8      0.99     0.01          raikkonen      12          9
# 9      1.00     0.00              kvyat      11         10
# 10     1.00     0.00              sainz       6         11
# 11     1.00     0.00              gasly       8         12
# 12     1.00     0.00            leclerc      13         13
# 13     1.00     0.00             vettel      14         14
# 14     1.00     0.00         giovinazzi      16         15
# 15     1.00     0.00            russell      15         16
# 16     1.00     0.00  pietro_fittipaldi      19         17
# 17     1.00     0.00             latifi      17         18
# 18     1.00     0.00              perez      20         19
# 19     1.00     0.00    kevin_magnussen      18         20

# %%
#what if we retrain the model after every single race, including the most recent predicted race into the training dataset

# %%
test = df[(df.season == 2022) & (df['round'] == 1)]
X_test = test.drop(['driver', 'podium', 'constructor_points_after_race', 'constructor_wins_after_race', 'constructor_standings_pos_after_race'], axis = 1)
y_test = test.podium

        #scaling
X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns)

        # make predictions
prediction_df = pd.DataFrame(model.predict_proba(X_test), columns = ['proba_0', 'proba_1'])
prediction_df['driver'] = test['driver'].reset_index(drop=True)
prediction_df['actual'] = y_test.reset_index(drop = True)
prediction_df.sort_values('proba_1', ascending = False, inplace = True)
prediction_df.reset_index(inplace = True, drop = True)
prediction_df['predicted'] = prediction_df.index + 1
#prediction_df['predicted'] = prediction_df.predicted.map(lambda x: 1 if x == 0 else 0)
